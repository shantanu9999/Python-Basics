# %%
DATA TYPES IN PYTHON
int =  2
list = [1,2,3,"python","c"]
tuple = (1,2,3,4,5)
float = 45.56
dict = {'name':'john','lastname':'clay','rollno':56}
str = 'Pthon'   "Python"    ''' Python'''
set = {1,2,3,4,5}
bool = True,  False

# %%
MUTABLE AND IMMUTABLE DATATYPES

MUTABLE:
    list
    dict
    set
IMMUTABLE:
    int
    float
    str
    tuple

# %%
itrable and non iterable dataypes

iterable:
    list
    tuple
    dict
    set
    str
non iterable data types 
    int
    float

# %%
_first_name = 
First_n6ame26 =

# %%
Operators in Python :
    Arithmetic Operator
    + , - ,* ,/ ,// ,% ,**
    Assignment Operator 
    = , += ,-=, *=, /= ,%= ,**=
    Comparision Operators
    == ,!= ,<= ,>= ,= ,< , >
    Logical Operator
    and or not
    Identity Operator
    is is not
    Membership Operator
    in not in
    Bitwise Operator
    &, | ,^ , ~ ,<< , >>

# %%
roll = 20
sum = roll + 10
print(sum)
# Out:
# 30

# %%
roll = 20
roll **=10
print(roll)
# Out:
# 10240000000000

# %%
l = [10,20,30,40]
p = [10,20,30,40]
print(l is p)
# Out:
# False

# %%
sum1 = 20
sum2 = 20

print(sum1 is not sum2)
# Out:
# False

# %%
Conditional Statements
    if 
    elif
    else

# %%
num1 = 5.5
num2 = 5

if num1 > num2 :
    print("num1 is greater than num2")
elif num2 > num1:
    print("num2 is greater than num1")
else:
    print("Both are same")
# Out:
# num1 is greater than num2

# %%
PEP 8

# %%
looping statements:
    for 
    while

# %%
sample_string = "I love python"

for avenger in sample_string:
    print(avenger + " a lot")
# Out:
# I a lot
#   a lot
# l a lot
# o a lot
# v a lot
# e a lot
#   a lot
# p a lot
# y a lot
# t a lot
# h a lot
# o a lot
# n a lot

# %%
l = [1,2,3,4,5,6,7,8,10......200]
for value in l:
    print(value * 3)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 30

# %%
for value in range(1,201):
    print(value * 3)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99
# 102
# 105
# 108
# 111
# 114
# 117
# 120
# 123
# 126
# 129
# 132
# 135
# 138
# 141
# 144
# 147
# 150
# 153
# 156
# 159
# 162
# 165
# 168
# 171
# 174
# 177
# 180
# 183
# 186
# 189
# 192
# 195
# 198
# 201
# 204
# 207
# 210
# 213
# 216
# 219
# 222
# 225
# 228
# 231
# 234
# 237
# 240
# 243
# 246
# 249
# 252
# 255
# 258
# 261
# 264
# 267
# 270
# 273
# 276
# 279
# 282
# 285
# 288
# 291
# 294
# 297
# 300
# 303
# 306
# 309
# 312
# 315
# 318
# 321
# 324
# 327
# 330
# 333
# 336
# 339
# 342
# 345
# 348
# 351
# 354
# 357
# 360
# 363
# 366
# 369
# 372
# 375
# 378
# 381
# 384
# 387
# 390
# 393
# 396
# 399
# 402
# 405
# 408
# 411
# 414
# 417
# 420
# 423
# 426
# 429
# 432
# 435
# 438
# 441
# 444
# 447
# 450
# 453
# 456
# 459
# 462
# 465
# 468
# 471
# 474
# 477
# 480
# 483
# 486
# 489
# 492
# 495
# 498
# 501
# 504
# 507
# 510
# 513
# 516
# ...

# %%
100 ... 200

# %%
for value in range(100,201,20):
    print(value)
# Out:
# 100
# 120
# 140
# 160
# 180
# 200

# %%
pass
break
continue

# %%
l = [10,20,30,40,-50,60,70,-80]

for value in l:
    if value < 0:
        print("Number is Negative", value)
        
        print("abc")
    else:
        print(value)
# Out:
# 10
# 20
# 30
# 40
# Number is Negative -50

# %%
if 100:
    print("Hi")
else:
    pass

# %%
sample_string = "Python is programming language"

vowel_count = 0
consonent_count = 0

for value in sample_string:
    if value in "aeiouAEIOU":
        vowel_count +=1
    elif value == " ":
        continue
        
    else:
        consonent_count +=1
print(vowel_count, consonent_count)
# Out:
# 9 18

# %%
l = [10,20,30,50,60]
print(l[2])
# Out:
# 30

# %%
nums = [10,20,30,4,50,60]
for index,value in enumerate(nums):
    print(index,value)
# Out:
# 0 10
# 1 20
# 2 30
# 3 4
# 4 50
# 5 60

# %%
for value1 in range(1,6):
    for value2 in range(100,201):
        print(value1 * value2)
# Out:
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 200
# 202
# 204
# 206
# 208
# 210
# 212
# 214
# 216
# 218
# 220
# 222
# 224
# 226
# 228
# 230
# 232
# 234
# 236
# 238
# 240
# 242
# 244
# 246
# 248
# 250
# 252
# 254
# 256
# 258
# 260
# 262
# 264
# 266
# 268
# 270
# 272
# 274
# 276
# 278
# 280
# 282
# 284
# 286
# 288
# 290
# 292
# 294
# 296
# 298
# 300
# 302
# 304
# 306
# 308
# 310
# 312
# 314
# 316
# 318
# 320
# 322
# 324
# 326
# 328
# ...

# %%
while loop:

while [condition]  => True or False
    statement
    statement

# %%
num1 = 5

5 * 4 * 3 * 2 * 1 =

# %%
num1 = 5
result = 1
while num1 > 1:
    result = result * num1  
    num1 -=1
print(result)
# Out:
# 120

# %%
while [condition]:
    statement

# %%
while 100:
    print ("infinite")
